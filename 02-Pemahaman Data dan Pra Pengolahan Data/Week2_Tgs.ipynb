# %% [markdown]
# <a href="https://colab.research.google.com/github/eeswepe/pembelajaran-mesin-sem-5/blob/main/02-Pemahaman%20Data%20dan%20Pra%20Pengolahan%20Data/Week2_Tgs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-226f6a2d-19e6-485e-af98-7be2153c5a5c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-226f6a2d-19e6-485e-af98-7be2153c5a5c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# #**Load Data**

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder, StandardScaler
import numpy as np
import matplotlib.pyplot as plt
dpath = '/content/wbc.csv'
df = pd.read_csv(dpath)
df.head(100)
# Out:
#           id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0     842302         M       17.990         10.38          122.80     1001.0
# 1     842517         M       20.570         17.77          132.90     1326.0
# 2   84300903         M       19.690         21.25          130.00     1203.0
# 3   84348301         M       11.420         20.38           77.58      386.1
# 4   84358402         M       20.290         14.34          135.10     1297.0
# ..       ...       ...          ...           ...             ...        ...
# 95     86208         M       20.260         23.03          132.40     1264.0
# 96     86211         B       12.180         17.84           77.79      451.1
# 97    862261         B        9.787         19.94           62.11      294.5
# 98    862485         B       11.600         12.84           74.34      412.6
# 99    862548         M       14.420         19.77           94.48      642.5
#
# ...

# %% [markdown]
# 1. Pisahkan antara variabel yang dapat digunakan dan variabel yang tidak dapat digunakan.
#     - variabel yang dapat digunakan adalah diagnosis dan beberapa variabel pendukung diagnosis
#     - variabel yang dapat dibuang yaitu variabel id dan juga unnamed karena seperti kolom unnamed tidak memberikan informasi

# %% [markdown]
# Hasil Ketika menghapus kolom id dan unnamed

# %%
df = df.drop(columns=["id", "Unnamed: 32"])
df.head()
# Out:
#   diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0         M        17.99         10.38          122.80     1001.0
# 1         M        20.57         17.77          132.90     1326.0
# 2         M        19.69         21.25          130.00     1203.0
# 3         M        11.42         20.38           77.58      386.1
# 4         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %% [markdown]
# Hasil ketika memisahkan kolom target dan fitur, dengan diagnosis sebagai target

# %%
X = df.drop(columns=["diagnosis"])
y = df["diagnosis"]

y.head(100)
# Out:
# 0     M
# 1     M
# 2     M
# 3     M
# 4     M
#      ..
# 95    M
# 96    B
# 97    B
# 98    B
# 99    M
# Name: diagnosis, Length: 100, dtype: object

# %% [markdown]
# 2. Lakukan proses encoding pada kolom "diagnosis".

# %%
y = df['diagnosis'].map({
    'B': 0,
    'M': 1
})

y.head(100)
# Out:
# 0     1
# 1     1
# 2     1
# 3     1
# 4     1
#      ..
# 95    1
# 96    0
# 97    0
# 98    0
# 99    1
# Name: diagnosis, Length: 100, dtype: int64

# %% [markdown]
# 3. Lakukan proses standardisasi pada semua kolom yang memiliki nilai numerik.

# %%
scaler = StandardScaler()

X = pd.DataFrame(
    scaler.fit_transform(X),
    columns=X.columns,
    index=X.index
)

x.head()
# Out:
# X:
#    radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0     1.097064     -2.073335        1.269934   0.984375         1.568466
# 1     1.829821     -0.353632        1.685955   1.908708        -0.826962
# 2     1.579888      0.456187        1.566503   1.558884         0.942210
# 3    -0.768909      0.253732       -0.592687  -0.764464         3.283553
# 4     1.750297     -1.151816        1.776573   1.826229         0.280372
#
#    compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 0          3.283515        2.652874             2.532475       2.217515
# 1         -0.487072       -0.023846             0.548144       0.001392
# 2          1.052926        1.363478             2.037231       0.939685
# 3          3.402909        1.915897             1.451707       2.867383
# 4          0.539340        1.371011             1.428493      -0.009560
#
#    fractal_dimension_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...
